# %%
import random
import time
import ahorcado

n = 0
aciertos = 0
resultado = 0
usuario = 0

def suma():
    global resultado, usuario 
    numero1 = random.randint(1, 100)
    numero2 = random.randint(1, 100)
    resultado = numero1 + numero2
    print(f'Cuanto es {numero1} + {numero2}?')
    usuario = int(input())
    time.sleep(2)

def resta():
    global resultado, usuario 
    numero1 = random.randint(1, 100)
    numero2 = random.randint(1, numero1)
    resultado = numero1 - numero2
    print(f'Cuanto es {numero1} - {numero2}?')
    usuario = int(input())
    time.sleep(2)

def multiplicacion():
    global resultado, usuario 
    numero1 = random.randint(1, 10)
    numero2 = random.randint(1, 10)
    resultado = numero1 * numero2
    print(f'Cuanto es {numero1} multiplicado por {numero2}?')
    usuario = int(input())
    time.sleep(2)

def division():
    global resultado, usuario 
    numero1 = random.randint(1, 10)
    numero2 = random.randint(1, 10)
    numero3 = numero1 * numero2
    resultado = numero1
    print(f'Cuanto es {numero3} dividido por {numero2}?')
    usuario = int(input())
    time.sleep(2)


while True:
    operacion = random.randint(1, 4)
    time.sleep(2)
    if operacion == 1:
        suma()
    elif operacion == 2:
        resta()
    elif operacion == 3:
        multiplicacion()
    elif operacion == 4:
        division()
    
    if resultado != usuario:
        n = n + 1
        if n == 10:
            print('Incorrecto...')
            time.sleep(2)
            ahorcado.formato(n)
            print('Perdiste...')
            time.sleep(2)
            print('Intenta de nuevo...')
            break
        else:
            print('Incorrecto...')
            time.sleep(2)
            ahorcado.formato(n)
    else:
        aciertos = aciertos + 1
        if aciertos == 10:
            print('Correcto!!!')
            time.sleep(2)
            print('Alcanzaste las 10 respuestas correctas!!!')
            time.sleep(2)
            print('Buen juego!!!')
            break
        else:
            print('Correcto!!!')
            time.sleep(2)
            print(f'Llevas {aciertos} respuestas correctas!!!')
